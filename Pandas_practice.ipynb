# %% [markdown]
# <a href="https://colab.research.google.com/github/Akanksha-Ceris/Pandas_practice/blob/main/Pandas_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas  as pd
runs = [23,56,78]
pd.Series(runs)
# Out:
# 0    23
# 1    56
# 2    78
# dtype: int64

# %%
# custom index
marks = [45,67,89]
subjects =['math','englis','hindi']
pd.Series(marks,index=subjects)
# Out:
# math      45
# englis    67
# hindi     89
# dtype: int64

# %%
# customer code
marks = [34,56,78]
subjects =['maths','englsh','science']
pd.Series(marks,index=subjects)
# Out:
# maths      34
# englsh     56
# science    78
# dtype: int64

# %%
# setting a name
marks = pd.Series(marks,index = subjects,name = 'Nitish ke marks' )
print(marks)
# Out:
# maths      34
# englsh     56
# science    78
# Name: Nitish ke marks, dtype: int64

# %% [markdown]
# Series from dict

# %%
marks = {
    'maths':67,
    'english':57,
    'science':89,
    'hindi':100
}
marks_series = pd.Series(marks,name ='akanksha ke marks')
marks_series
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: akanksha ke marks, dtype: int64

# %% [markdown]
# Series Attributes

# %%
# size
marks_series
{ 'maths':67,'english':57,'science': 89,'hindi':100}
print(marks_series.size)
# Out:
# 4

# %%
#dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
# name
marks_series.name
# Out:
# 'akanksha ke marks'

# %%
# is_unique
marks_series.is_unique
pd.Series([1,2,1,3,5]).is_unique
# Out:
# False

# %%
#index
marks_series.index
# Out:
# Index(['maths', 'english', 'science', 'hindi'], dtype='object')

# %%
# values
marks_series.values
# Out:
# array([ 67,  57,  89, 100])

# %% [markdown]
# # New Section

# %%
import pandas
mydataset = {
    'cars' :["BMW","VOLVO","FORD"],
    'passigns':[3,7,2]

}
myvar = pandas.DataFrame(mydataset)
print(myvar)
# Out:
#     cars  passigns
# 0    BMW         3
# 1  VOLVO         7
# 2   FORD         2

# %%
import pandas as pd

# %%
mydataset = {
    'cars':["BMV","VOLVO","FORD"],
    'passings':[3,7,2]

}
myvar = pd.DataFrame(mydataset)
print(myvar)
# Out:
#     cars  passings
# 0    BMV         3
# 1  VOLVO         7
# 2   FORD         2

# %%
#  date is 5 of march 2026
# crate a simple pandas as pd
import pandas as pd
a = [1,7,2]
myvar = pd.Series(a)
print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
# return the first value of the Series
print(myvar[0])
# Out:
# 1

# %%
# create your own labels:
a = [1,7,2]
myvar = pd.Series(a,index = ["x","y","z"])
print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
# when you have created labels , you can access an item by referring to the label
# example:
# return  the value of "y"
print(myvar["y"])
# Out:
# 7

# %% [markdown]
#  key/Values Objects as Series

# %%
# create a  simple pandas Series from a dictonary:
calories = {"day1":345,"day2":789,"day3":783}
myvar = pd.Series(calories)
print(myvar)
# here the keys of the dictionary become the labels
# Out:
# day1    345
# day2    789
# day3    783
# dtype: int64

# %%
# create  a Series using only data from "day1" and "day2":

myvar = pd.Series(calories,index=["day1","day2"])
print(myvar)
# Out:
# day1    345
# day2    789
# dtype: int64

# %% [markdown]
# DataFrames

# %% [markdown]
# Data sets in pandas are usually multi-dimensional tables ,called Dataframes
# series is like a column , a DataFrame is the whole table

# %%
# create a Dataframe from  two series
data = {
    "calories":[234,56,789],
    "duration":[50,40,45]
}
myvar = pd.DataFrame(data)
print(myvar)
# Out:
#    calories  duration
# 0       234        50
# 1        56        40
# 2       789        45

# %% [markdown]
# Locate Row

# %% [markdown]
# What is Dataframe?
# A pandas Dataframe is a 2 dimensional data structure ,like a 2 dimensional array, or a table with rows and columns.

# %%
# Create a simple Pandas Dataframe
data = {
    "colories":[789,34,56],
    "duration":[56,34,56]

    }
    #load data into a Dataframe objects:
df = pd.DataFrame(data)
print(df)
# Out:
#    colories  duration
# 0       789        56
# 1        34        34
# 2        56        56

# %%
# use a list of indexes:
print(df.loc[[0,1]])
# Out:
#    colories  duration
# 0       789        56
# 1        34        34

# %% [markdown]
# # Named Indexes

# %%
# with the index argunment , you can  name your own indexes
# Add a list of names to give each row a name:
data = {
    "calories":[420,380,390],
    "duration":[50,40,45]
}
df = pd.DataFrame(data,index=["day1","day2","day3"])
print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %% [markdown]
# Locate

# %% [markdown]
# Load Files into a DataFrame
# If your data sets are stored in a file, Pandas can load them into  a DataFRame

# %%
# Load a comma deparated file(CSV file ) into a Dataframe

# %%
import pandas as pd

# %% [markdown]
# Series using read_csv

# %%
# with one col

# %% [markdown]
# Series using read_csv

# %%
# with one col
subs=pd.read_csv('/content/subs.csv').squeeze("columns")
subs
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_217/2230517912.py in <cell line: 0>()
#       1 # with one col
# ----> 2 subs=pd.read_csv('/content/subs.csv').squeeze("columns")
#       3 subs
#
# ...

# %%
# with 2 cols
vk =pd.read_csv('/content/kohli_ipl.csv',index_col='match_no').squeeze("columns")
print(vk)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_217/3830976123.py in <cell line: 0>()
#       1 # with 2 cols
# ----> 2 vk =pd.read_csv('/content/kohli_ipl.csv',index_col='match_no').squeeze("columns")
#       3 print(vk)
#
# ...

# %% [markdown]
# Series methods

# %%
# head and tail
# it provide top 5 rows of dataseet
subs.head()
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
vk.head(3)
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# Name: runs, dtype: int64

# %%
# Tail
vk.tail()
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
# it provide last 10 matches of ipl
vk.tail(10)
# Out:
# match_no
# 206     0
# 207     0
# 208     9
# 209    58
# 210    30
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
# sample. it select  columns randomly
vk.sample()
# Out:
# match_no
# 63    45
# Name: runs, dtype: int64

# %%
# show randomly 5 columns from the dataset
vk.sample(5)
# Out:
# match_no
# 208     9
# 173    29
# 103    51
# 35      3
# 131    54
# Name: runs, dtype: int64

# %%
# value counts
cars=pd.read_csv('/content/cars.csv')
cars
# Out:
#         brand  km_driven    fuel                 owner  selling_price
# 0      Maruti     145500  Diesel           First Owner         450000
# 1       Skoda     120000  Diesel          Second Owner         370000
# 2       Honda     140000  Petrol           Third Owner         158000
# 3     Hyundai     127000  Diesel           First Owner         225000
# 4      Maruti     120000  Petrol           First Owner         130000
# ...       ...        ...     ...                   ...            ...
# 8123  Hyundai     110000  Petrol           First Owner         320000
# 8124  Hyundai     119000  Diesel  Fourth & Above Owner         135000
# 8125   Maruti     120000  Diesel           First Owner         382000
# 8126     Tata      25000  Diesel           First Owner         290000
# 8127     Tata      25000  Diesel           First Owner         290000
#
# [8128 rows x 5 columns]

# %%
vk.value_counts()
# Out:
# runs
# 0     9
# 1     8
# 12    8
# 9     7
# 8     6
#      ..
# 46    1
# 29    1
# 84    1
# 90    1
# 53    1
# Name: count, Length: 78, dtype: int64

# %%
# sort values4# method chaning
vk.sort_values(ascending = False).head(1).values[0]
# Out:
# np.int64(113)

# %%
cars.sort_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_217/2081644350.py in <cell line: 0>()
# ----> 1 cars.sort_index()
#
# NameError: name 'cars' is not defined

# %%
# sort_index -> inplace -> movies
cars.sort_index(inplace = True)
cars
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_217/4237878587.py in <cell line: 0>()
#       1 # sort_index -> inplace -> movies
# ----> 2 cars.sort_index(inplace = True)
#       3 cars
#
# NameError: name 'cars' is not defined

# %%
# Data cleaning : missing values,invalid values

# %%
# size mutability

# %%
# statical analysis

# %%
# programming language _python
# math:statics

# %%
# primary data structure
# 1 series: 1D
#2 DataFRame  2 D

# %%
import pandas as pd

# %%
s = pd.Series ([12,45,67,88])
print(s)
# Out:
# 0    12
# 1    45
# 2    67
# 3    88
# dtype: int64

# %%
s

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.values
# Out:
# array([12, 45, 67, 88])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
s.name

# %%
print(s.name)
# Out:
# None

# %%
s.name="numbers"
s
# Out:
# 0    12
# 1    45
# 2    67
# 3    88
# Name: numbers, dtype: int64

# %%
# Indexing

# %%
s[0]
# Out:
# np.int64(12)

# %%
# If i want multiple element

# %%
s[0:2]# # start(included): stop (excluded):step value (value to jump)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_543/1004294245.py in <cell line: 0>()
# ----> 1 s[0:2]# # start(included): stop (excluded):step value (value to jump)
#
# NameError: name 's' is not defined

# %%
s[2:4]
# Out:
# 2    67
# 3    88
# Name: numbers, dtype: int64

# %%
#iloc -> location based indexing
s.iloc[3]
# Out:
# np.int64(88)

# %%
s.iloc[[0,1,2]]
# Out:
# 0    12
# 1    45
# 2    67
# Name: numbers, dtype: int64

# %%
s.name = "claories"# I have changed the column  name to colories
s
# Out:
# 0    12
# 1    45
# 2    67
# 3    88
# Name: claories, dtype: int64

# %%
index = ["apple","banana","grapes","orange"]
s.index= index
s
# Out:
# apple     12
# banana    45
# grapes    67
# orange    88
# dtype: int64

# %%
s['grapes']
# Out:
# np.int64(67)

# %%
s.iloc[3]
# Out:
# np.int64(88)

# %%
#loc -> label based indexing
s.loc['grapes']
# Out:
# np.int64(67)

# %% [markdown]
# In label based indexing your start as well as stop value both are included in the output

# %%
print(s)
# Out:
# apple     12
# banana    45
# grapes    67
# orange    88
# Name: numbers, dtype: int64

# %%
s["apple":"ornage"]
# Out:
# apple     12
# banana    45
# grapes    67
# orange    88
# dtype: int64

# %%
# how i can create series using dictionary
fruit_protien = {
    "Avocado":2.0,
    "Guava":2.6,
    "Blackberries":2.0, # grams of protein
    "Oranges":0.9,
    "Banana":1.1,
    "kiwi":1.1,
    "Pomeogranate":1.7,
    "Mango":0.8,
    "Cherries":1.0

}

# %%
s2 = pd.Series(fruit_protien)
name = "protein"
print(s2)
# Out:
# Avocado         2.0
# Guava           2.6
# Blackberries    2.0
# Oranges         0.9
# Banana          1.1
# kiwi            1.1
# Pomeogranate    1.7
# Mango           0.8
# Cherries        1.0
# dtype: float64

# %%
# conditional selection
# i want to   find the protien_fruit which is greater than 1
s2>1
# Out:
# Avocado          True
# Guava            True
# Blackberries     True
# Oranges         False
# Banana           True
# kiwi             True
# Pomeogranate     True
# Mango           False
# Cherries        False
# dtype: bool

# %%
s2[s2>1]
# Out:
# Avocado         2.0
# Guava           2.6
# Blackberries    2.0
# Banana          1.1
# kiwi            1.1
# Pomeogranate    1.7
# dtype: float64

# %%
# Logical Operator.# and operator
[(s2>0.5) & (s2>2)]
# Out:
# [Avocado         False
#  Guava            True
#  Blackberries    False
#  Oranges         False
#  Banana          False
#  kiwi            False
#  Pomeogranate    False
#  Mango           False
#  Cherries        False
#  dtype: bool]

# %%
# or operator
s2[(s2>0.5) |  (s2 <= 2)]
# Out:
# Avocado         2.0
# Guava           2.6
# Blackberries    2.0
# Oranges         0.9
# Banana          1.1
# kiwi            1.1
# Pomeogranate    1.7
# Mango           0.8
# Cherries        1.0
# dtype: float64

# %%
# not operator
s2[~(s2>1)]
# Out:
# Oranges     0.9
# Mango       0.8
# Cherries    1.0
# dtype: float64

# %%
# modifying the series:
s2 ["mango" ] = 2.8
s2
# Out:
# Avocado         2.0
# Guava           2.6
# Blackberries    2.0
# Oranges         0.9
# Banana          1.1
# kiwi            1.1
# Pomeogranate    1.7
# Mango           0.8
# Cherries        1.0
# mango           2.8
# dtype: float64

# %%
import numpy as np

# %%
ser = pd.Series(['a',np.nan,1,np.nan,2])
s.notnull().sum()
# Out:
# np.int64(4)

# %%
data = {
    "Name":["Alice","Bob","Charlie","David","Eve","Alice"],
    "Age" :[25,30,35,np.nan,29,25],
    "Department":["HR","IT","Finanace","IT","HR","HR"], # dataframe

    "Salary":[50000,60000,70000,62000,np.nan,50000]
}

# %%
data
# Out:
# {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Alice'],
#  'Age': [25, 30, 35, nan, 29, 25],
#  'Department': ['HR', 'IT', 'Finanace', 'IT', 'HR', 'HR'],
#  'Salary': [50000, 60000, 70000, 62000, nan, 50000]}

# %%
df = pd.DataFrame(data)
df
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0   Finanace  70000.0
# 3    David   NaN         IT  62000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  50000.0

# %%
df.head(2)
# Out:
#     Name   Age Department   Salary
# 0  Alice  25.0         HR  50000.0
# 1    Bob  30.0         IT  60000.0

# %%
df.tail(2)
# Out:
#     Name   Age Department   Salary
# 4    Eve  29.0         HR      NaN
# 5  Alice  25.0         HR  50000.0

# %%
# loc and iloc\
df.iloc[1:3]
# Out:
#       Name   Age Department   Salary
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0   Finanace  70000.0

# %%
df.loc[1:2,["Age","Department"]] # rows
# Out:
#     Age Department
# 1  30.0         IT
# 2  35.0   Finanace

# %%
df["Age"]
# Out:
# 0    25.0
# 1    30.0
# 2    35.0
# 3     NaN
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64

# %%
df[["Age","Department"]]
# Out:
#     Age Department
# 0  25.0         HR
# 1  30.0         IT
# 2  35.0   Finanace
# 3   NaN         IT
# 4  29.0         HR
# 5  25.0         HR

# %%
df.drop("Age",axis = 1,inplace = True)

# %%
data
# Out:
# {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Alice'],
#  'Age': [25, 30, 35, nan, 29, 25],
#  'Department': ['HR', 'IT', 'Finanace', 'IT', 'HR', 'HR'],
#  'Salary': [50000, 60000, 70000, 62000, nan, 50000]}

# %%
df.head(2)
# Out:
#     Name   Age Department   Salary
# 0  Alice  25.0         HR  50000.0
# 1    Bob  30.0         IT  60000.0

# %%
df.tail(3)
# Out:
#     Name   Age Department   Salary
# 3  David   NaN         IT  62000.0
# 4    Eve  29.0         HR      NaN
# 5  Alice  25.0         HR  50000.0

# %%
# loc and iloc
df.iloc[1:3]
# Out:
#       Name   Age Department   Salary
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0   Finanace  70000.0

# %%
df.loc[1:3,["Age","Department"]]
# Out:
#     Age Department
# 1  30.0         IT
# 2  35.0   Finanace
# 3   NaN         IT

# %%
df.iloc[1:3, :2]# rows ,column
# Out:
#       Name   Age
# 1      Bob  30.0
# 2  Charlie  35.0

# %%
df[["Age","Department"]]
# Out:
#     Age Department
# 0  25.0         HR
# 1  30.0         IT
# 2  35.0   Finanace
# 3   NaN         IT
# 4  29.0         HR
# 5  25.0         HR

# %%
# drop age column
df.drop("Age",axis = 1)
# Out:
#       Name Department   Salary
# 0    Alice         HR  50000.0
# 1      Bob         IT  60000.0
# 2  Charlie   Finanace  70000.0
# 3    David         IT  62000.0
# 4      Eve         HR      NaN
# 5    Alice         HR  50000.0

# %%
df
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0   Finanace  70000.0
# 3    David   NaN         IT  62000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  50000.0

# %%
# shpe of dataset
df.shape
# Out:
# (6, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        6 non-null      object
#  1   Age         5 non-null      float64
#  2   Department  6 non-null      object
#  3   Salary      5 non-null      float64
# dtypes: float64(2), object(2)
# memory usage: 324.0+ bytes

# %%
df.describe()
# Out:
#              Age        Salary
# count   5.000000      5.000000
# mean   28.800000  58400.000000
# std     4.147288   8532.291603
# min    25.000000  50000.000000
# 25%    25.000000  50000.000000
# 50%    29.000000  60000.000000
# 75%    30.000000  62000.000000
# max    35.000000  70000.000000

# %%
df["Salary"]
# Out:
# 0    50000.0
# 1    60000.0
# 2    70000.0
# 3    62000.0
# 4        NaN
# 5    50000.0
# Name: Salary, dtype: float64

# %%
#Broadcasting
df["Salary"] = df["Salary"] + 5000

# %%
df["Salary"]
# Out:
# 0    60000.0
# 1    70000.0
# 2    80000.0
# 3    72000.0
# 4        NaN
# 5    60000.0
# Name: Salary, dtype: float64

# %%
# Renaiming columns:
df.rename(columns={"Department": "Dept"},inplace = True)

# %%
df["Dept"].unique()
# Out:
# array(['HR', 'IT', 'Finanace'], dtype=object)

# %%
df["Dept"].value_counts()
# Out:
# Dept
# HR          3
# IT          2
# Finanace    1
# Name: count, dtype: int64

# %%
df["Promoted Salary"] = df["Salary"] * 10
df
# Out:
#       Name   Age      Dept   Salary  Promoted Salary
# 0    Alice  25.0        HR  60000.0         600000.0
# 1      Bob  30.0        IT  70000.0         700000.0
# 2  Charlie  35.0  Finanace  80000.0         800000.0
# 3    David   NaN        IT  72000.0         720000.0
# 4      Eve  29.0        HR      NaN              NaN
# 5    Alice  25.0        HR  60000.0         600000.0

# %%
# data cleaning

# %%
df.isnull().sum()
# Out:
# Name               0
# Age                1
# Dept               0
# Salary             1
# Promoted Salary    1
# dtype: int64

# %%
# Missing values
df.fillna(0)
# Out:
#       Name   Age      Dept   Salary  Promoted Salary
# 0    Alice  25.0        HR  60000.0         600000.0
# 1      Bob  30.0        IT  70000.0         700000.0
# 2  Charlie  35.0  Finanace  80000.0         800000.0
# 3    David   0.0        IT  72000.0         720000.0
# 4      Eve  29.0        HR      0.0              0.0
# 5    Alice  25.0        HR  60000.0         600000.0

# %%
df["Age"].fillna(df["Age"].mean())
# Out:
# 0    25.0
# 1    30.0
# 2    35.0
# 3    28.8
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64

# %%
df["Salary"].fillna(df["Salary"].median())
# Out:
# 0    60000.0
# 1    70000.0
# 2    80000.0
# 3    72000.0
# 4    70000.0
# 5    60000.0
# Name: Salary, dtype: float64

# %%
df["Age"].fillna(method = "ffill")
# Out:
# /tmp/ipykernel_543/544980945.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["Age"].fillna(method = "ffill")
# 0    25.0
# 1    30.0
# 2    35.0
# 3    28.8
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64

# %%
df["Age"].fillna(method = "bfill")
# Out:
# /tmp/ipykernel_543/3026805218.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["Age"].fillna(method = "bfill")
# 0    25.0
# 1    30.0
# 2    35.0
# 3    28.8
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64

# %%
df["Name"]=df["Name"].replace("Charlie","Rose")
df
# Out:
#     Name   Age      Dept   Salary  Promoted Salary
# 0  Alice  25.0        HR  60000.0         600000.0
# 1    Bob  30.0        IT  70000.0         700000.0
# 2   Rose  35.0  Finanace  80000.0         800000.0
# 3  David  28.8        IT  72000.0         720000.0
# 4    Eve  29.0        HR      NaN              NaN
# 5  Alice  25.0        HR  60000.0         600000.0

# %%
# how  to deal with duplicate  values
df_dup = df[df.duplicated(keep = "first")]
df_dup
# Out:
#     Name   Age Dept   Salary  Promoted Salary
# 5  Alice  25.0   HR  60000.0         600000.0

# %%
df_dump = df[df.duplicated(keep = "last")]
df_dump
# Out:
#     Name   Age Dept   Salary  Promoted Salary
# 0  Alice  25.0   HR  60000.0         600000.0

# %%
df = df.drop_duplicates()
df
# Out:
#     Name   Age      Dept   Salary  Promoted Salary
# 0  Alice  25.0        HR  60000.0         600000.0
# 1    Bob  30.0        IT  70000.0         700000.0
# 2   Rose  35.0  Finanace  80000.0         800000.0
# 3  David  28.8        IT  72000.0         720000.0
# 4    Eve  29.0        HR      NaN              NaN

# %%
# invaalid values:
# Lambda -> python
df["promoted salary"] =  df["Promoted Salary"].apply(lambda x: x /10 if x > 650000 else x)

# %%
name = "alice_fernandes"
df[["first_name","last_name"]] = df["name"].str.split("_")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_543/1403245022.py in <cell line: 0>()
#       1 name = "alice_fernandes"
# ...

# %%
# apply and lambda
def multiplying_age(x):
   return x*2
df["Age"] = df["Age"].apply(multiplying_age)
df
# Out:
#     Name     Age      Dept   Salary  Promoted Salary  promoted salary
# 0  Alice  1600.0        HR  60000.0         600000.0         600000.0
# 1    Bob  1920.0        IT  70000.0         700000.0          70000.0
# 2   Rose  2240.0  Finanace  80000.0         800000.0          80000.0
# 3  David  1843.2        IT  72000.0         720000.0          72000.0
# 4    Eve  1856.0        HR      NaN              NaN              NaN

# %% [markdown]
# Joins and Merges

# %%
department_info = {
  "Department":["HR","IT","Finance"],
  "Location":["New York","San Francisco","Chicago"],
  "Manager":["Laura","Steve","Nina"]}
df2 = pd.DataFrame(department_info)
df2
# Out:
#   Department       Location Manager
# 0         HR       New York   Laura
# 1         IT  San Francisco   Steve
# 2    Finance        Chicago    Nina

# %%
pd.concat([df,df2])
# Out:
#     Name     Age      Dept   Salary  Promoted Salary  promoted salary  \
# 0  Alice  1600.0        HR  60000.0         600000.0         600000.0
# 1    Bob  1920.0        IT  70000.0         700000.0          70000.0
# 2   Rose  2240.0  Finanace  80000.0         800000.0          80000.0
# 3  David  1843.2        IT  72000.0         720000.0          72000.0
# 4    Eve  1856.0        HR      NaN              NaN              NaN
# 0    NaN     NaN       NaN      NaN              NaN              NaN
# 1    NaN     NaN       NaN      NaN              NaN              NaN
# 2    NaN     NaN       NaN      NaN              NaN              NaN
#
#   Department       Location Manager
# 0        NaN            NaN     NaN
# 1        NaN            NaN     NaN
# 2        NaN            NaN     NaN
# 3        NaN            NaN     NaN
# 4        NaN            NaN     NaN
# 0         HR       New York   Laura
# 1         IT  San Francisco   Steve
# 2    Finance        Chicago    Nina

# %%
pd.merge(df,df2,on = "Dept")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_543/2494343359.py in <cell line: 0>()
# ----> 1 pd.merge(df,df2,on = "Dept")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#
# ...

# %%
data = pd.read("datascvfile")
# head give gives first 5 rows of dataset

# %%
# data shape: it gives the rows and column
